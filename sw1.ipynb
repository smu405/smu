# %% [markdown]
# # 변수의 선언과 사용
#
# * 문제1: 반지름을 3.14로 정의하고 원의 면적과 둘레를 계산하는 프로그램 작성

# %%
from IPython.display import Image
import os

dir=os.getcwd()
print dir
Image(filename=os.path.join(dir,'uml/uml_simple.png'))
# Out:
# /home/jsl/Code/git/bb/p2

# %%
phi=3.14
radius=10
circumference=2*phi*radius
area=phi*radius**2
print "원의 둘레는",circumference
print "원의 면적은", area
# Out:
# 원의 둘레는 62.8
# 원의 면적은 314.0
